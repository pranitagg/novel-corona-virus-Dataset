# %%
import pandas as pd

# %%
d =pd.read_csv('/kaggle/input/novel-corona-virus-2019-dataset/covid_19_data.csv')
d
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %% [markdown]
# **Datatype change with to_datatime**

# %%
d['Last Update']=pd.to_datetime(d['Last Update'])

# %%
d['ObservationDate']=pd.to_datetime(d['ObservationDate'])

# %%
d
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      2020-01-22              Anhui  Mainland China
# 1            2      2020-01-22            Beijing  Mainland China
# 2            3      2020-01-22          Chongqing  Mainland China
# 3            4      2020-01-22             Fujian  Mainland China
# 4            5      2020-01-22              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      2021-05-29  Zaporizhia Oblast         Ukraine
# 306425  306426      2021-05-29            Zeeland     Netherlands
# 306426  306427      2021-05-29           Zhejiang  Mainland China
# 306427  306428      2021-05-29    Zhytomyr Oblast         Ukraine
# 306428  306429      2021-05-29       Zuid-Holland     Netherlands
#
#                Last Update  Confirmed  Deaths  Recovered
# 0      2020-01-22 17:00:00        1.0     0.0        0.0
# 1      2020-01-22 17:00:00       14.0     0.0        0.0
# ...

# %%
mask = d['Country/Region'] == 'India'

# %%
mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 306424    False
# 306425    False
# 306426    False
# 306427    False
# 306428    False
# Name: Country/Region, Length: 306429, dtype: bool

# %%
mask1 = d['Province/State'] == 'Gansu'

# %%
mask1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 306424    False
# 306425    False
# 306426    False
# 306427    False
# 306428    False
# Name: Province/State, Length: 306429, dtype: bool

# %%
mask2 = d['ObservationDate']=='2021-05-29'

# %%
mask2
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 306424     True
# 306425     True
# 306426     True
# 306427     True
# 306428     True
# Name: ObservationDate, Length: 306429, dtype: bool

# %% [markdown]
# **multiple with two column**

# %%
d[mask & mask2]
# Out:
#            SNo ObservationDate                            Province/State  \
# 305855  305856      2021-05-29               Andaman and Nicobar Islands
# 305856  305857      2021-05-29                            Andhra Pradesh
# 305873  305874      2021-05-29                         Arunachal Pradesh
# 305874  305875      2021-05-29                                     Assam
# 305896  305897      2021-05-29                                     Bihar
# 305930  305931      2021-05-29                                Chandigarh
# 305937  305938      2021-05-29                              Chhattisgarh
# 305956  305957      2021-05-29  Dadra and Nagar Haveli and Daman and Diu
# 305960  305961      2021-05-29                                     Delhi
# 305996  305997      2021-05-29                                       Goa
# 306012  306013      2021-05-29                                   Gujarat
# 306018  306019      2021-05-29                                   Haryana
# ...

# %% [markdown]
# **isin**

# %%
data =d['Country/Region'].isin(['India','Japan','China'])

# %%
d[data]
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 35          36      2020-01-22            NaN          Japan
# 38          39      2020-01-22        Unknown          China
# 75          76      2020-01-23            NaN          Japan
# 86          87      2020-01-23        Unknown          China
# 123        124      2020-01-24            NaN          Japan
# ...        ...             ...            ...            ...
# 306401  306402      2021-05-29       Wakayama          Japan
# 306406  306407      2021-05-29    West Bengal          India
# 306413  306414      2021-05-29       Yamagata          Japan
# 306414  306415      2021-05-29      Yamaguchi          Japan
# 306416  306417      2021-05-29      Yamanashi          Japan
#
#                Last Update  Confirmed   Deaths  Recovered
# 35     2020-01-22 17:00:00        2.0      0.0        0.0
# 38     2020-01-22 17:00:00        0.0      0.0        0.0
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  datetime64[ns]
#  2   Province/State   228329 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  datetime64[ns]
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(2)
# memory usage: 18.7+ MB

# %%
mask3 = d['Province/State'].isnull()

# %%
d[mask3]
# Out:
#            SNo ObservationDate Province/State      Country/Region  \
# 35          36      2020-01-22            NaN               Japan
# 36          37      2020-01-22            NaN            Thailand
# 37          38      2020-01-22            NaN         South Korea
# 39          40      2020-01-22            NaN            Kiribati
# 75          76      2020-01-23            NaN               Japan
# ...        ...             ...            ...                 ...
# 305831  305832      2021-05-29            NaN             Vietnam
# 305832  305833      2021-05-29            NaN  West Bank and Gaza
# 305833  305834      2021-05-29            NaN               Yemen
# 305834  305835      2021-05-29            NaN              Zambia
# 305835  305836      2021-05-29            NaN            Zimbabwe
#
#                Last Update  Confirmed  Deaths  Recovered
# 35     2020-01-22 17:00:00        2.0     0.0        0.0
# 36     2020-01-22 17:00:00        4.0     0.0        2.0
# ...

# %%
mask4 =d['Province/State'].notnull()

# %%
d[mask4].head()
# Out:
#    SNo ObservationDate Province/State  Country/Region         Last Update  \
# 0    1      2020-01-22          Anhui  Mainland China 2020-01-22 17:00:00
# 1    2      2020-01-22        Beijing  Mainland China 2020-01-22 17:00:00
# 2    3      2020-01-22      Chongqing  Mainland China 2020-01-22 17:00:00
# 3    4      2020-01-22         Fujian  Mainland China 2020-01-22 17:00:00
# 4    5      2020-01-22          Gansu  Mainland China 2020-01-22 17:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %% [markdown]
# **between()**

# %%
mask5 = d['ObservationDate'].between('2020-01-22','2020-01-23')
mask5
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 306424    False
# 306425    False
# 306426    False
# 306427    False
# 306428    False
# Name: ObservationDate, Length: 306429, dtype: bool

# %%
d[mask5]
# Out:
#     SNo ObservationDate Province/State  Country/Region         Last Update  \
# 0     1      2020-01-22          Anhui  Mainland China 2020-01-22 17:00:00
# 1     2      2020-01-22        Beijing  Mainland China 2020-01-22 17:00:00
# 2     3      2020-01-22      Chongqing  Mainland China 2020-01-22 17:00:00
# 3     4      2020-01-22         Fujian  Mainland China 2020-01-22 17:00:00
# 4     5      2020-01-22          Gansu  Mainland China 2020-01-22 17:00:00
# ..  ...             ...            ...             ...                 ...
# 83   84      2020-01-23            NaN          Mexico 2020-01-23 17:00:00
# 84   85      2020-01-23            NaN          Brazil 2020-01-23 17:00:00
# 85   86      2020-01-23            NaN        Colombia 2020-01-23 17:00:00
# 86   87      2020-01-23        Unknown           China 2020-01-23 17:00:00
# 87   88      2020-01-23            NaN        Kiribati 2020-01-23 17:00:00
#
#     Confirmed  Deaths  Recovered
# 0         1.0     0.0        0.0
# ...

# %%
mask6 = d['Confirmed'].between(12,14)

# %%
d[mask6]
# Out:
#            SNo ObservationDate          Province/State  Country/Region  \
# 1            2      2020-01-22                 Beijing  Mainland China
# 197        198      2020-01-26                 Tianjin  Mainland China
# 198        199      2020-01-26                   Hebei  Mainland China
# 248        249      2020-01-27                   Gansu  Mainland China
# 249        250      2020-01-27                  Shanxi  Mainland China
# ...        ...             ...                     ...             ...
# 304732  304733      2021-05-27  Repatriated Travellers          Canada
# 305234  305235      2021-05-28          Grand Princess          Canada
# 305497  305498      2021-05-28  Repatriated Travellers          Canada
# 305999  306000      2021-05-29          Grand Princess          Canada
# 306262  306263      2021-05-29  Repatriated Travellers          Canada
#
#                Last Update  Confirmed  Deaths  Recovered
# 1      2020-01-22 17:00:00       14.0     0.0        0.0
# ...

# %%
f = {
    
    'stud':["riya","siya","tiya","piya","kiya"],
    'mark':[55,22,23,24,53],
    'age':[12,11,14,12,11]
}

df =pd.DataFrame(f)
df
# Out:
#    stud  mark  age
# 0  riya    55   12
# 1  siya    22   11
# 2  tiya    23   14
# 3  piya    24   12
# 4  kiya    53   11

# %%
mask = df['mark'].duplicated(keep =False)#keep attribute have only 3 value "first","last","False"

# %%
df[mask]
# Out:
# Empty DataFrame
# Columns: [stud, mark, age]
# Index: []

# %%
df.loc[2:4]
# Out:
#    stud  mark  age
# 2  tiya    23   14
# 3  piya    24   12
# 4  kiya    53   11

# %%
m1 =df.duplicated(subset =['stud','mark','age'] )
m1
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df
# Out:
#    stud  mark  age
# 0  riya    55   12
# 1  siya    22   11
# 2  tiya    23   14
# 3  piya    24   12
# 4  kiya    53   11

# %%
df[m1]
# Out:
# Empty DataFrame
# Columns: [stud, mark, age]
# Index: []

# %%
ff =pd.read_csv('/kaggle/input/novel-corona-virus-2019-dataset/covid_19_data.csv')
ff
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
m2 =ff.duplicated(subset =['ObservationDate','Province/State','Country/Region','Last Update'])
m2
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 306424    False
# 306425    False
# 306426    False
# 306427    False
# 306428    False
# Length: 306429, dtype: bool

# %%
ff[m2]
# Out:
#     SNo ObservationDate Province/State  Country/Region    Last Update  \
# 53   54      01/23/2020          Hubei  Mainland China  1/23/20 17:00
#
#     Confirmed  Deaths  Recovered
# 53      444.0    17.0       28.0

# %%
m3 =ff.duplicated(subset =['ObservationDate','Province/State','Country/Region','Last Update'],keep=False)
m3   #using keep ="False" attribute we see the duplicate records
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 306424    False
# 306425    False
# 306426    False
# 306427    False
# 306428    False
# Length: 306429, dtype: bool

# %%
ff[m3]
# Out:
#     SNo ObservationDate Province/State  Country/Region    Last Update  \
# 49   50      01/23/2020          Hubei  Mainland China  1/23/20 17:00
# 53   54      01/23/2020          Hubei  Mainland China  1/23/20 17:00
#
#     Confirmed  Deaths  Recovered
# 49      444.0    17.0       28.0
# 53      444.0    17.0       28.0

# %%
ff.loc[30:38]  #is property is used to show the record between start to end the list
# Out:
#     SNo ObservationDate Province/State  Country/Region      Last Update  \
# 30   31      01/22/2020          Tibet  Mainland China  1/22/2020 17:00
# 31   32      01/22/2020     Washington              US  1/22/2020 17:00
# 32   33      01/22/2020       Xinjiang  Mainland China  1/22/2020 17:00
# 33   34      01/22/2020         Yunnan  Mainland China  1/22/2020 17:00
# 34   35      01/22/2020       Zhejiang  Mainland China  1/22/2020 17:00
# 35   36      01/22/2020            NaN           Japan  1/22/2020 17:00
# 36   37      01/22/2020            NaN        Thailand  1/22/2020 17:00
# 37   38      01/22/2020            NaN     South Korea  1/22/2020 17:00
# 38   39      01/22/2020        Unknown           China  1/22/2020 17:00
#
#     Confirmed  Deaths  Recovered
# 30        0.0     0.0        0.0
# 31        1.0     0.0        0.0
# 32        0.0     0.0        0.0
# 33        1.0     0.0        0.0
# 34       10.0     0.0        0.0
# 35        2.0     0.0        0.0
# ...

# %%
df
# Out:
#    stud  mark  age
# 0  riya    55   12
# 1  siya    22   11
# 2  tiya    23   14
# 3  piya    24   12
# 4  kiya    53   11

# %%
df.drop_duplicates() #it shows the duplicate records
# Out:
#    stud  mark  age
# 0  riya    55   12
# 1  siya    22   11
# 2  tiya    23   14
# 3  piya    24   12
# 4  kiya    53   11

# %%
df.drop_duplicates(keep =False)  #bez of keep attribute its shows non-duplicate
# Out:
#    stud  mark  age
# 0  riya    55   12
# 1  siya    22   11
# 2  tiya    23   14
# 3  piya    24   12
# 4  kiya    53   11

# %%
df
# Out:
#    stud  mark  age
# 0  riya    55   12
# 1  siya    22   11
# 2  tiya    23   14
# 3  piya    24   12
# 4  kiya    53   11

# %%
df.drop_duplicates(ignore_index=True )
# Out:
#    stud  mark  age
# 0  riya    55   12
# 1  siya    22   11
# 2  tiya    23   14
# 3  piya    24   12
# 4  kiya    53   11

# %%
df.drop_duplicates(ignore_index=True ,subset=['stud','age'])
# Out:
#    stud  mark  age
# 0  riya    55   12
# 1  siya    22   11
# 2  tiya    23   14
# 3  piya    24   12
# 4  kiya    53   11

# %%
ff
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
ff.drop_duplicates(ignore_index=False ,subset=['ObservationDate','Province/State','Country/Region'])
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
m3 =ff.drop_duplicates(keep =False)
m3
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
ff['Province/State'].unique()  #retrun unique value of col
# Out:
# array(['Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu', 'Guangdong',
#        'Guangxi', 'Guizhou', 'Hainan', 'Hebei', 'Heilongjiang', 'Henan',
#        'Hong Kong', 'Hubei', 'Hunan', 'Inner Mongolia', 'Jiangsu',
#        'Jiangxi', 'Jilin', 'Liaoning', 'Macau', 'Ningxia', 'Qinghai',
#        'Shaanxi', 'Shandong', 'Shanghai', 'Shanxi', 'Sichuan', 'Taiwan',
#        'Tianjin', 'Tibet', 'Washington', 'Xinjiang', 'Yunnan', 'Zhejiang',
#        nan, 'Unknown', 'Chicago', 'Illinois', 'California', 'Arizona',
#        'Ontario', 'New South Wales', 'Victoria', 'British Columbia',
#        'Bavaria', 'Queensland', 'Chicago, IL', 'South Australia',
#        'Boston, MA', 'Los Angeles, CA', 'Orange, CA', 'Santa Clara, CA',
#        'Seattle, WA', 'Tempe, AZ', 'San Benito, CA', 'Toronto, ON',
#        'London, ON', 'Madison, WI', 'Cruise Ship',
#        'Diamond Princess cruise ship', 'San Diego County, CA',
#        'San Antonio, TX', 'Ashland, NE', 'Travis, CA',
# ...

# %%
ff['Province/State'].nunique()  #retrun no of unique value of col  count
# Out:
# 737

# %% [markdown]
# **we can give the condition ******

# %%
ff['Confirmed'].sum() / ff['Province/State'].nunique()
# Out:
# 35620151.63907734

# %% [markdown]
# > **DATA EXTRACTION**

# %%
a = pd.read_csv('/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv',index_col=['Company'])
a
# Out:
#                                                                              Job_Role  \
# Company
# UPL                                                             Senior Data Scientist
# Walmart                                                         Senior Data Scientist
# SAP India Pvt.Ltd                   Applied Data Scientist / ML Senior Engineer (P...
# UPL                                                                    Data Scientist
# Walmart                                                                Data Scientist
# ...                                                                               ...
# Krazy Mantra HR Solutions Pvt. Ltd                Tech Lead/Architect ( Contractual )
# cliqhr.com                                                       Tech Lead / POD Lead
# Serving Skill                          Java Full Stack Developer - Hibernate / Spring
# cliqhr.com                                                          Tech Lead - Azure
# ...

# %%
a.set_index('Job_Role',inplace =False)
# Out:
#                                                                                              Location  \
# Job_Role
# Senior Data Scientist                                         Bangalore/Bengaluru, Mumbai (All Areas)
# Senior Data Scientist                                                             Bangalore/Bengaluru
# Applied Data Scientist / ML Senior Engineer (Py...                                Bangalore/Bengaluru
# Data Scientist                                                Bangalore/Bengaluru, Mumbai (All Areas)
# Data Scientist                                                                    Bangalore/Bengaluru
# ...                                                                                               ...
# Tech Lead/Architect ( Contractual )                             Kolkata, Chennai, Bangalore/Bengaluru
# Tech Lead / POD Lead                                Hyderabad/Secunderabad, Pune, Bangalore/Bengaluru
# ...

# %% [markdown]
# **set_index**

# %%
a.set_index('Location',append =True)  #concatinate the two columns
#if append= False then it will show only location Column
# Out:
#                                                                                                                                 Job_Role  \
# Company                            Location
# UPL                                Bangalore/Bengaluru, Mumbai (All Areas)                                         Senior Data Scientist
# Walmart                            Bangalore/Bengaluru                                                             Senior Data Scientist
# SAP India Pvt.Ltd                  Bangalore/Bengaluru                                 Applied Data Scientist / ML Senior Engineer (P...
# UPL                                Bangalore/Bengaluru, Mumbai (All Areas)                                                Data Scientist
# Walmart                            Bangalore/Bengaluru                                                                    Data Scientist
# ...

# %%
a.reset_index(col_level=1)
# Out:
#                                   Company  \
# 0                                     UPL
# 1                                 Walmart
# 2                       SAP India Pvt.Ltd
# 3                                     UPL
# 4                                 Walmart
# ...                                   ...
# 11995  Krazy Mantra HR Solutions Pvt. Ltd
# 11996                          cliqhr.com
# 11997                       Serving Skill
# 11998                          cliqhr.com
# 11999           Huquo Consulting Pvt. Ltd
#
#                                                 Job_Role  \
# 0                                  Senior Data Scientist
# 1                                  Senior Data Scientist
# 2      Applied Data Scientist / ML Senior Engineer (P...
# 3                                         Data Scientist
# 4                                         Data Scientist
# ...                                                  ...
# ...

# %%
a.loc['Walmart'].rank(ascending =False)
# Out:
#          Job_Role  Location  Job Experience  Skills/Description
# Company
# Walmart      36.0      33.5            14.0                51.0
# Walmart      52.0      33.5            27.5                31.0
# Walmart      44.5      33.5             5.5                50.0
# Walmart      52.0      33.5            27.5                52.0
# Walmart      36.0      33.5            19.0                18.0
# Walmart       8.5      33.5            27.5                13.0
# Walmart       8.5      33.5            27.5                47.0
# Walmart      33.0      33.5            14.0                26.0
# Walmart      36.0      33.5            14.0                29.0
# Walmart      36.0      33.5             1.0                 6.0
# Walmart      36.0      33.5            14.0                16.0
# Walmart      43.0      33.5            60.0                22.0
# Walmart      49.0      33.5             7.5                12.0
# Walmart      44.5      33.5             5.5                 4.0
# ...

# %%
a.sort_index(ascending =True)# mutiple row access
# Out:
#                                                                  Job_Role  \
# Company
# 01MARCOM                                             Full Stack Developer
# 11Milliondream Consultancy Services                  Senior Data Engineer
# 18 Steps Consultants                                   BI Support Analyst
# 24 7 ai                                 Software Development Engineer 3 -
# 24 7 ai                                          Principal Data Scientist
# ...                                                                   ...
# zBliss Technologies                                 Data Scientist Intern
# zBliss Technologies                                 Data Scientist Intern
# zCodelabs Software Services                                Data Scientist
# zMed Healthcare Technologies                        Data Scientist Intern
# zeotap                               Software Engineer - Data Engineering
#
# ...

# %%
a.loc[['Walmart','Serving Skill']]
# Out:
#                                                      Job_Role  \
# Company
# Walmart                                 Senior Data Scientist
# Walmart                                        Data Scientist
# Walmart                              Principal Data Scientist
# Walmart                                        Data Scientist
# Walmart                                 Senior Data Scientist
# ...                                                       ...
# Serving Skill   Java Full Stack Developer - Hibernate/ Spring
# Serving Skill  Informatica/Cloud Developer - ETL/Snowflake DB
# Serving Skill  Informatica/Cloud Developer - ETL/Snowflake DB
# Serving Skill   Java Full Stack Developer - Hibernate/ Spring
# Serving Skill  Java Full Stack Developer - Hibernate / Spring
#
#                                                         Location  \
# Company
# Walmart                                      Bangalore/Bengaluru
# Walmart                                      Bangalore/Bengaluru
# ...

# %% [markdown]
# **iloc accessor (index loc)**

# %%
a.iloc[2]
# Out:
# Job_Role              Applied Data Scientist / ML Senior Engineer (P...
# Location                                            Bangalore/Bengaluru
# Job Experience                                                     5-10
# Skills/Description    Python, IT Skills, Testing, Cloud, Product Man...
# Name: SAP India Pvt.Ltd, dtype: object

# %%
a.iloc[[1,34,66,55]]
# Out:
#                                                                            Job_Role  \
# Company
# Walmart                                                       Senior Data Scientist
# Tesco Bengaluru                                      Manager Applied Data Scientist
# Accumed Practice Management DMCC                                 Sr. Data Scientist
# Huquo Consulting Pvt. Ltd         Assistant Manager/Manager/Senior Manager - Dat...
#
#                                                                Location  \
# Company
# Walmart                                             Bangalore/Bengaluru
# Tesco Bengaluru                                     Bangalore/Bengaluru
# Accumed Practice Management DMCC                                Chennai
# Huquo Consulting Pvt. Ltd         Gurgaon/Gurugram, Bangalore/Bengaluru
#
#                                  Job Experience  \
# Company
# Walmart                                     5-9
# Tesco Bengaluru                             3-6
# ...

# %%
a.iloc[20:30:2]
# Out:
#                                                                 Job_Role  \
# Company
# Pfizer                 Manager, Data Scientist/AI and Machine Learnin...
# Eli Lilly and Company                           Associate Data Scientist
# novo                                               Senior Data Scientist
# Accenture                        Sr. Clinical Data Programming Scientist
# Michelin                                           Senior Data Scientist
#
#                                   Location Job Experience  \
# Company
# Pfizer                             Chennai            2-3
# Eli Lilly and Company  Bangalore/Bengaluru            2-6
# novo                      Gurgaon/Gurugram            4-8
# Accenture              Bangalore/Bengaluru           7-11
# Michelin                              Pune            3-7
#
#                                                       Skills/Description
# Company
# Pfizer                 Computer science, data science, Neural network...
# ...

# %%
a.loc['Pfizer' ,"Job_Role"]
# Out:
# Company
# Pfizer    Manager, Data Scientist/AI and Machine Learnin...
# Pfizer    Manager, Senior Clinical Data Scientist, Clini...
# Pfizer                 Manager, Lead Data Scientist (R CoE)
# Pfizer    Sr. Scientist / Sr. Associate - Data Visualiza...
# Pfizer    Data Scientist - Hybrid Modeling & Process con...
# Pfizer    Senior Associate, Senior Reporting Analyst, Da...
# Pfizer    Senior Associate, Senior Data Manager, Clinica...
# Pfizer         Senior Data Manager - Clinical Data Sciences
# Pfizer                   Asset Lead- Clinical Data Sciences
# Pfizer            Senior Associate, Senior Database Analyst
# Pfizer                      Business Analyst, India Digital
# Pfizer                              Associate - LPS Analyst
# Name: Job_Role, dtype: object

# %%
a.loc['Pfizer',["Location","Job_Role"]]
# Out:
#         Location                                           Job_Role
# Company
# Pfizer   Chennai  Manager, Data Scientist/AI and Machine Learnin...
# Pfizer   Chennai  Manager, Senior Clinical Data Scientist, Clini...
# Pfizer    Mumbai               Manager, Lead Data Scientist (R CoE)
# Pfizer   Chennai  Sr. Scientist / Sr. Associate - Data Visualiza...
# Pfizer   Chennai  Data Scientist - Hybrid Modeling & Process con...
# Pfizer   Chennai  Senior Associate, Senior Reporting Analyst, Da...
# Pfizer   Chennai  Senior Associate, Senior Data Manager, Clinica...
# Pfizer   Chennai       Senior Data Manager - Clinical Data Sciences
# Pfizer   Chennai                 Asset Lead- Clinical Data Sciences
# Pfizer   Chennai          Senior Associate, Senior Database Analyst
# Pfizer    Mumbai                    Business Analyst, India Digital
# Pfizer   Chennai                            Associate - LPS Analyst

# %%
a.loc[:,["Location","Job_Role"]].head()  #slicing
# Out:
#                                                   Location  \
# Company
# UPL                Bangalore/Bengaluru, Mumbai (All Areas)
# Walmart                                Bangalore/Bengaluru
# SAP India Pvt.Ltd                      Bangalore/Bengaluru
# UPL                Bangalore/Bengaluru, Mumbai (All Areas)
# Walmart                                Bangalore/Bengaluru
#
#                                                             Job_Role
# Company
# UPL                                            Senior Data Scientist
# Walmart                                        Senior Data Scientist
# SAP India Pvt.Ltd  Applied Data Scientist / ML Senior Engineer (P...
# UPL                                                   Data Scientist
# Walmart                                               Data Scientist

# %%
a
# Out:
#                                                                              Job_Role  \
# Company
# UPL                                                             Senior Data Scientist
# Walmart                                                         Senior Data Scientist
# SAP India Pvt.Ltd                   Applied Data Scientist / ML Senior Engineer (P...
# UPL                                                                    Data Scientist
# Walmart                                                                Data Scientist
# ...                                                                               ...
# Krazy Mantra HR Solutions Pvt. Ltd                Tech Lead/Architect ( Contractual )
# cliqhr.com                                                       Tech Lead / POD Lead
# Serving Skill                          Java Full Stack Developer - Hibernate / Spring
# cliqhr.com                                                          Tech Lead - Azure
# ...

# %%
a['Skills/Description'].unique()
# Out:
# array(['python, MLT, statistical modeling, machine learning, IT Skills, advanced analytics, scala, statistics',
#        'Data Science, Machine learning, Python, Azure, BiqQuery, GCP, PySpark, tensorflow',
#        'Python, IT Skills, Testing, Cloud, Product Management, SAP, Cloud computing, NLP',
#        ...,
#        'AirFlow, BigQuery, GCS, Kafka, Java, Shell script, RDBMS, Python',
#        'PowerShell, Azure Data Factory, Azure, PaaS, MDM, SaaS, IaaS, Azure Data Lake',
#        'Java, JavaScript, Machine Learning, NoSQL, Cloud Computing, Full Stack, AWS, SQL'],
#       dtype=object)

# %%
a.loc["python, MLT, statistical modeling, machine learning, IT Skills, advanced analytics, scala, statistics":"Data Science, Machine learning, Python, Azure, BiqQuery, GCP, PySpark, tensorflow","Job_Role":"Job Experience"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:162, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:203, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:211, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
df

# %%
df.loc["siya":"piya","stud":"age"]

# %%
a = pd.read_csv('/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv',index_col=['Skills/Description'])
a

# %%
a.loc["python, MLT, statistical modeling, machine learning, IT Skills, advanced analytics, scala, statistics":"IT Skills, Python, Data Science, Machine Learning, Big Data, Computer science, Computer vision, deep learning","Job_Role":"Location"]

# %%
aa =pd.read_csv("/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv" ,index_col ="Company")
aa

# %%
aa.rename (mapper ={
    "Data Scientist":"Data analayst",
    "Tech Lead / POD Lead":"ML Learning"
} ,axis =0 )

# %%
aa["Company"].nunique()

# %%
aa.rename (mapper ={
    "cliqhr.com":"cliqHR.com",
    "Walmart":"Walmart2"
} ,axis =0 ,inplace =True )

# %%
aa

# %%
aa.rename(index = {
    "Data Scientist":"Senior Senior Data Scientist",
    "Tech Lead / POD Lead":"Machine Learning"
},inplace =True)

# %%
aa

# %%
aa.rename (mapper ={
    "cliqHR.com":"cliqhr.com",
    "Walmart2":"Walmart"
} ,axis =0 ,inplace =True )

# %%
aa

# %%
aa.drop(labels ="UPL" ,inplace =True)

# %%
aa

# %%
aa.drop(labels ="Job_Role" , axis =1)

# %%
aa.sample(n =1)

# %%
aa.sample(n = 20, replace =True)

# %%
import numpy as np

# %%
aa['salary']=np.random.randint(400000,4000000,12000)

# %%
aa

# %%
aa.sort_values("salary",ascending =True,inplace = True)

# %%
aa.head(3)

# %%
aa.nlargest(3,"salary")

# %%
aa.nsmallest(4 ,"salary")               (# no of rows and columns)
